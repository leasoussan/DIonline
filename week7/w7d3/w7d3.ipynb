# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import random

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')
pd.get_dummies(df, columns=['species'])
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species_setosa  \
# 0             5.1          3.5           1.4          0.2               1
# 1             4.9          3.0           1.4          0.2               1
# 2             4.7          3.2           1.3          0.2               1
# 3             4.6          3.1           1.5          0.2               1
# 4             5.0          3.6           1.4          0.2               1
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3               0
# 146           6.3          2.5           5.0          1.9               0
# 147           6.5          3.0           5.2          2.0               0
# 148           6.2          3.4           5.4          2.3               0
# 149           5.9          3.0           5.1          1.8               0
#
#      species_versicolor  species_virginica
# ...

# %%
rank_list = ["Great", "Good", "Okay", "Bad", "Poor"]
items = pd.Series([random.choice(rank_list) for i in range(100)])

# %%
items
# Out:
# 0       Bad
# 1      Poor
# 2       Bad
# 3     Great
# 4      Poor
#       ...
# 95     Poor
# 96    Great
# 97     Good
# 98     Good
# 99     Poor
# Length: 100, dtype: object

# %%
size_dict = {'Poor': 0, 'Bad':1, 'Okay':2, 'Good':3, 'Great':4}
encoded_items = items.map(lambda x: size_dict[x])

# %%
encoded_items
# Out:
# 0     1
# 1     0
# 2     1
# 3     4
# 4     0
#      ..
# 95    0
# 96    4
# 97    3
# 98    3
# 99    0
# Length: 100, dtype: int64

# %%
pd.DataFrame({"Rank": items, "Encoded_item": encoded_items})
# Out:
#      Rank  Encoded_item
# 0     Bad             1
# 1    Poor             0
# 2     Bad             1
# 3   Great             4
# 4    Poor             0
# ..    ...           ...
# 95   Poor             0
# 96  Great             4
# 97   Good             3
# 98   Good             3
# 99   Poor             0
#
# [100 rows x 2 columns]

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')
pd.get_dummies(df, columns=['species'])
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species_setosa  \
# 0             5.1          3.5           1.4          0.2               1
# 1             4.9          3.0           1.4          0.2               1
# 2             4.7          3.2           1.3          0.2               1
# 3             4.6          3.1           1.5          0.2               1
# 4             5.0          3.6           1.4          0.2               1
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3               0
# 146           6.3          2.5           5.0          1.9               0
# 147           6.5          3.0           5.2          2.0               0
# 148           6.2          3.4           5.4          2.3               0
# 149           5.9          3.0           5.1          1.8               0
#
#      species_versicolor  species_virginica
# ...

# %%
cars = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')
pd.get_dummies(cars, columns=["Manufacturer"])
# Out:
#       Model     Type  Min.Price  Price  Max.Price  MPG.city  MPG.highway  \
# 0   Integra    Small       12.9   15.9       18.8      25.0         31.0
# 1    Legend  Midsize       29.2   33.9       38.7      18.0         25.0
# 2        90  Compact       25.9   29.1       32.3      20.0         26.0
# 3       100  Midsize        NaN   37.7       44.6      19.0         26.0
# 4      535i  Midsize        NaN   30.0        NaN      22.0         30.0
# ..      ...      ...        ...    ...        ...       ...          ...
# 88  Eurovan      Van       16.6   19.7       22.7      17.0         21.0
# 89   Passat  Compact       17.6   20.0       22.4      21.0         30.0
# 90  Corrado   Sporty       22.9   23.3       23.7      18.0         25.0
# 91      240  Compact       21.8   22.7       23.5      21.0         28.0
# 92      850  Midsize       24.8   26.7       28.5      20.0         28.0
#
#                AirBags DriveTrain Cylinders  ...  Manufacturer_Oldsmobile  \
# ...

# %%
means = cars[['Manufacturer', 'Price']].groupby('Manufacturer').mean()
cars['Manufacturer_transformed'] = cars['Manufacturer'].dropna().apply(lambda x: means.loc[x, "Price"])
cars[['Manufacturer', 'Manufacturer_transformed', 'Price']].head()
# Out:
#   Manufacturer  Manufacturer_transformed  Price
# 0        Acura                      15.9   15.9
# 1          NaN                       NaN   33.9
# 2         Audi                      33.4   29.1
# 3         Audi                      33.4   37.7
# 4          BMW                      30.0   30.0

# %%
means
# Out:
#                    Price
# Manufacturer
# Acura          15.900000
# Audi           33.400000
# BMW            30.000000
# Buick          21.625000
# Cadillac       37.400000
# Chevrolet      18.187500
# Chrysler       22.650000
# Dodge          15.700000
# Eagle          15.750000
# Ford           14.962500
# Geo            10.450000
# Honda          16.466667
# Hyundai        10.475000
# Infiniti       47.900000
# Lexus          28.000000
# Lincoln        35.200000
# Mazda          17.600000
# Mercedes-Benz  46.900000
# Mercury        14.500000
# Mitsubishi     18.200000
# Nissan         17.025000
# Oldsmobile     17.500000
# Plymouth       14.400000
# Pontiac        16.140000
# Saab           28.700000
# Saturn               NaN
# Subaru         12.933333
# Suzuki          8.600000
# Toyota         16.966667
# Volkswagen     18.025000
# Volvo          22.700000

# %%
cars
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1           NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2          Audi       90  Compact       25.9   29.1       32.3      20.0
# 3          Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4           BMW     535i  Midsize        NaN   30.0        NaN      22.0
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7      17.0
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4      21.0
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7      18.0
# 91        Volvo      240  Compact       21.8   22.7       23.5      21.0
# 92          NaN      850  Midsize       24.8   26.7       28.5      20.0
#
#     MPG.highway             AirBags DriveTrain  ... Wheelbase  Width  \
# ...

# %%
cars.Make.unique()
# Out:
# array(['Acura Integra', 'Acura Legend', 'Audi 90', 'Audi 100', 'BMW 535i',
#        'Buick Century', 'Buick LeSabre', 'Buick Roadmaster',
#        'Buick Riviera', 'Cadillac DeVille', 'Cadillac Seville',
#        'Chevrolet Cavalier', 'Chevrolet Corsica', 'Chevrolet Camaro',
#        'Chevrolet Lumina', 'Chevrolet Lumina_APV', 'Chevrolet Astro',
#        'Chevrolet Caprice', 'Chevrolet Corvette', 'Chrylser Concorde',
#        'Chrysler LeBaron', 'Chrysler Imperial', 'Dodge Colt',
#        'Dodge Shadow', 'Dodge Spirit', 'Dodge Caravan', 'Dodge Dynasty',
#        'Dodge Stealth', 'Eagle Summit', 'Eagle Vision', 'Ford Festiva',
#        'Ford Escort', nan, 'Ford Mustang', 'Ford Probe', 'Ford Aerostar',
#        'Ford Taurus', 'Ford Crown_Victoria', 'Geo Metro', 'Geo Storm',
#        'Honda Prelude', 'Honda Civic', 'Honda Accord', 'Hyundai Excel',
#        'Hyundai Elantra', 'Hyundai Sonata', 'Infiniti Q45', 'Lexus ES300',
# ...

# %%
d = {v:i for i for i, v in enumerate(cars.Make.unique())}
# Out:
#   File "<ipython-input-42-54b80633ec43>", line 1
#     d = {v:ifor i for i, v in enumerate(cars.Make.unique())}
#                 ^
# SyntaxError: invalid syntax

# %%
encoded_items = items.map(lambda x: size_dict[x])
cars['make_encoded'] = encoded_items

# %% [markdown]
# question 2 process categorical w7d2

# %%
means = cars[['Model', 'Price']].groupby('Model').mean()
cars['Model_transformed'] = cars['Model'].dropna().apply(lambda x: means.loc[x, "Price"])
cars[['Model', 'Model_transformed', 'Price']].head()
# Out:
#      Model  Model_transformed  Price
# 0  Integra               15.9   15.9
# 1   Legend               33.9   33.9
# 2       90               29.1   29.1
# 3      100               37.7   37.7
# 4     535i               30.0   30.0

# %%
means
# Out:
#           Price
# Model
# 100        37.7
# 190E       31.9
# 240        22.7
# 300E       61.9
# 323         8.3
# ...         ...
# Taurus     20.2
# Tempo      11.3
# Tercel      9.8
# Town_Car   36.1
# Vision     19.3
#
# [92 rows x 1 columns]

# %%
cars.describe()
# Out:
#        Min.Price      Price  Max.Price   MPG.city  MPG.highway  EngineSize  \
# count  86.000000  91.000000  88.000000  84.000000    91.000000   91.000000
# mean   17.118605  19.616484  21.459091  22.404762    29.065934    2.658242
# std     8.828290   9.724280  10.696563   5.841520     5.370293    1.045845
# min     6.700000   7.400000   7.900000  15.000000    20.000000    1.000000
# 25%    10.825000  12.350000  14.575000  18.000000    26.000000    1.800000
# 50%    14.600000  17.700000  19.150000  21.000000    28.000000    2.300000
# 75%    20.250000  23.500000  24.825000  25.000000    31.000000    3.250000
# max    45.400000  61.900000  80.000000  46.000000    50.000000    5.700000
#
#        Horsepower          RPM  Rev.per.mile  Fuel.tank.capacity  ...  \
# count   86.000000    90.000000     87.000000           85.000000  ...
# mean   144.000000  5276.666667   2355.000000           16.683529  ...
# std     53.455204   605.554811    486.916616            3.375748  ...
# ...

# %%
# Dealing with No values
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              89 non-null     object
#  1   Model                     92 non-null     object
#  2   Type                      90 non-null     object
#  3   Min.Price                 86 non-null     float64
#  4   Price                     91 non-null     float64
#  5   Max.Price                 88 non-null     float64
#  6   MPG.city                  84 non-null     float64
#  7   MPG.highway               91 non-null     float64
#  8   AirBags                   87 non-null     object
#  9   DriveTrain                86 non-null     object
#  10  Cylinders                 88 non-null     object
#  11  EngineSize                91 non-null     float64
#  12  Horsepower                86 non-null     float64
# ...

# %% [markdown]
# # we can either file it with values or deleat the row
# # or complete nan with average or mean of themissing values

# %%
cars.isnull()
# Out:
#     Manufacturer  Model   Type  Min.Price  Price  Max.Price  MPG.city  \
# 0          False  False  False      False  False      False     False
# 1           True  False  False      False  False      False     False
# 2          False  False  False      False  False      False     False
# 3          False  False  False       True  False      False     False
# 4          False  False  False       True  False       True     False
# ..           ...    ...    ...        ...    ...        ...       ...
# 88         False  False  False      False  False      False     False
# 89         False  False  False      False  False      False     False
# 90         False  False  False      False  False      False     False
# 91         False  False  False      False  False      False     False
# 92          True  False  False      False  False      False     False
#
#     MPG.highway  AirBags  DriveTrain  ...  Turn.circle  Rear.seat.room  \
# ...

# %%
# give me what is null in length
cars.Length.isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 88    False
# 89    False
# 90    False
# 91    False
# 92    False
# Name: Length, Length: 93, dtype: bool

# %%
# to see which one are null >>maske
cars[cars.Length.isnull()]
# Out:
#      Manufacturer       Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 14      Chevrolet      Lumina  Midsize       13.4   15.9       18.4       NaN
# 58  Mercedes-Benz        300E  Midsize       43.8   61.9       80.0      19.0
# 69     Oldsmobile  Silhouette      Van       19.5   19.5       19.5      18.0
# 77           Saab         900  Compact       20.3   28.7       37.1      20.0
#
#     MPG.highway             AirBags DriveTrain  ... Turn.circle  \
# 14         29.0                None      Front  ...         NaN
# 58         25.0  Driver & Passenger       Rear  ...        37.0
# 69         23.0                None      Front  ...        44.0
# 77         26.0                 NaN      Front  ...        37.0
#
#     Rear.seat.room  Luggage.room  Weight   Origin                   Make  \
# 14            28.5          16.0  3195.0      USA       Chevrolet Lumina
# 58             NaN          15.0  3525.0  non-USA     Mercedes-Benz 300E
# ...

# %%
cars.Length.fillna(cars.Length.mean())
# Out:
# 0     177.0
# 1     195.0
# 2     180.0
# 3     193.0
# 4     186.0
#       ...
# 88    187.0
# 89    180.0
# 90    159.0
# 91    190.0
# 92    184.0
# Name: Length, Length: 93, dtype: float64

# %%
# now that we filed the na we have to replace
cars["Length"] = cars.Length.fillna(cars.Length.mean())

# %%
cars.Length.isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 88    False
# 89    False
# 90    False
# 91    False
# 92    False
# Name: Length, Length: 93, dtype: bool

# %%
# there is no more missing

# %% [markdown]
# OUTLIERS

# %%
plt.boxplot(cars.Weight.dropna())
plt.show()

# %% [markdown]
# # we see Highest value is 4000 majoriry between 2500 and 3500 the orange is average

# %%
plt.boxplot(cars["MPG.highway"].dropna())
plt.show()

# %%
# here we can see potential outliers the top round value - to check this first we will get the max 
cars["MPG.highway"].dropna().max()
# Out:
# 50.0

# %%
cars=cars

# %%
cars
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1           NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2          Audi       90  Compact       25.9   29.1       32.3      20.0
# 3          Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4           BMW     535i  Midsize        NaN   30.0        NaN      22.0
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7      17.0
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4      21.0
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7      18.0
# 91        Volvo      240  Compact       21.8   22.7       23.5      21.0
# 92          NaN      850  Midsize       24.8   26.7       28.5      20.0
#
#     MPG.highway             AirBags DriveTrain  ...   NaN  24.0  50.0  46.0  \
# ...

# %%
# lets get a mask to get the row 
cars[ cars["MPG.highway"] ==cars["MPG.highway"].max()]
# Out:
#    Manufacturer  Model   Type  Min.Price  Price  Max.Price  MPG.city  \
# 38          Geo  Metro  Small        6.7    8.4       10.0      46.0
#
#     MPG.highway AirBags DriveTrain  ... Passengers  Length  Wheelbase  Width  \
# 38         50.0    None      Front  ...        4.0   151.0       93.0   63.0
#
#     Turn.circle Rear.seat.room  Luggage.room  Weight   Origin       Make
# 38         34.0           27.5          10.0  1695.0  non-USA  Geo Metro
#
# [1 rows x 27 columns]

# %%
cars
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1           NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2          Audi       90  Compact       25.9   29.1       32.3      20.0
# 3          Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4           BMW     535i  Midsize        NaN   30.0        NaN      22.0
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7      17.0
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4      21.0
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7      18.0
# 91        Volvo      240  Compact       21.8   22.7       23.5      21.0
# 92          NaN      850  Midsize       24.8   26.7       28.5      20.0
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# ...

# %%
# then we put a mask 
car = cars[cars["MPG.highway"] < cars["MPG.highway"].max()]

# %%
iris_df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')

# %%
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split
