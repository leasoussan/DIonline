# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Ex 1 week 7 day1

# %%
def creatArray(start, length, step):
    return np.arange(start, start+length*step, step)
    
    
creatArray(6,100,4)
# Out:
# array([  6,  10,  14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,
#         58,  62,  66,  70,  74,  78,  82,  86,  90,  94,  98, 102, 106,
#        110, 114, 118, 122, 126, 130, 134, 138, 142, 146, 150, 154, 158,
#        162, 166, 170, 174, 178, 182, 186, 190, 194, 198, 202, 206, 210,
#        214, 218, 222, 226, 230, 234, 238, 242, 246, 250, 254, 258, 262,
#        266, 270, 274, 278, 282, 286, 290, 294, 298, 302, 306, 310, 314,
#        318, 322, 326, 330, 334, 338, 342, 346, 350, 354, 358, 362, 366,
#        370, 374, 378, 382, 386, 390, 394, 398, 402])

# %%
a = np.array([1,2,3,np.nan,5,6,7,np.nan])

# %%
a_withoutNan = a[~numpy.isnan(a)]

# %% [markdown]
# inside the array we are adding a mask to filter the values

# %%
a_withoutNan
# Out:
# array([1., 2., 3., 5., 6., 7.])

# %%
array = np.random.randint(1,101,30).reshape(5,6).max()

# %%
array.dtype
# Out:
# dtype('int32')

# %%
array = np.random.randint(1,101,30).reshape(5,6)

# %%
array
# Out:
# array([[73, 50, 68, 79, 38, 87],
#        [36,  9, 68, 13, 71, 58],
#        [59, 22, 47, 58, 75, 12],
#        [94, 72, 24, 65, 51, 74],
#        [58, 63, 33, 96, 87, 28]])

# %%
array.max()
# Out:
# 96

# %%
series = pd.Series(np.take(list('abcdefghijklmnop'), np.random.randint(16, size=500)))

# %%
series
# Out:
# 0      j
# 1      k
# 2      a
# 3      e
# 4      k
#       ..
# 495    p
# 496    p
# 497    l
# 498    f
# 499    b
# Length: 500, dtype: object

# %%
series.value_counts()
# Out:
# l    41
# a    39
# p    38
# f    37
# h    35
# j    31
# g    31
# b    30
# m    30
# i    29
# k    29
# o    27
# c    27
# d    27
# e    27
# n    22
# dtype: int64

# %%
series_date = pd.Series(['01 Jan 2020', '10-19-2020', '20150303', '2013/04/04', '2012-05-05', '2013-06-06T12:20'])

# %%
pd.to_datetime(series_date)
# Out:
# 0   2020-01-01 00:00:00
# 1   2020-10-19 00:00:00
# 2   2015-03-03 00:00:00
# 3   2013-04-04 00:00:00
# 4   2012-05-05 00:00:00
# 5   2013-06-06 12:20:00
# dtype: datetime64[ns]

# %%
pd.to_datetime(series_date).dt.year
# Out:
# 0    2020
# 1    2020
# 2    2015
# 3    2013
# 4    2012
# 5    2013
# dtype: int64

# %%
pd.to_datetime(series_date).dt.day_name()
# Out:
# 0    Wednesday
# 1       Monday
# 2      Tuesday
# 3     Thursday
# 4     Saturday
# 5     Thursday
# dtype: object

# %%
pd.to_datetime(series_date).dt.isocalendar().week
# Out:
# 0     1
# 1    43
# 2    10
# 3    14
# 4    18
# 5    23
# Name: week, dtype: UInt32

# %%
pd.to_datetime(series_date).dt.dayofyear
# Out:
# 0      1
# 1    293
# 2     62
# 3     94
# 4    126
# 5    157
# dtype: int64

# %%
data=  https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv
# Out:
#   File "<ipython-input-96-15e05d65e443>", line 1
#     data=  https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv
#                 ^
# SyntaxError: invalid syntax

# %%
data= pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')

# %%
data
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1           NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2          Audi       90  Compact       25.9   29.1       32.3      20.0
# 3          Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4           BMW     535i  Midsize        NaN   30.0        NaN      22.0
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7      17.0
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4      21.0
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7      18.0
# 91        Volvo      240  Compact       21.8   22.7       23.5      21.0
# 92          NaN      850  Midsize       24.8   26.7       28.5      20.0
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# ...

# %%
data.values_count
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-6f26fdb6e53b> in <module>
# ----> 1 data.values_count
#
# c:\users\lea soussan\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'values_count'

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Manufacturer        89 non-null     object
#  1   Model               92 non-null     object
#  2   Type                90 non-null     object
#  3   Min.Price           86 non-null     float64
#  4   Price               91 non-null     float64
#  5   Max.Price           88 non-null     float64
#  6   MPG.city            84 non-null     float64
#  7   MPG.highway         91 non-null     float64
#  8   AirBags             87 non-null     object
#  9   DriveTrain          86 non-null     object
#  10  Cylinders           88 non-null     object
#  11  EngineSize          91 non-null     float64
#  12  Horsepower          86 non-null     float64
#  13  RPM                 90 non-null     float64
#  14  Rev.per.mile        87 non-null     float64
# ...

# %%
data.rename(columns = {"Type": "TypeOfCar"}, inplace=True)

# %%
data
# Out:
#    Manufacturer    Model TypeOfCar  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra     Small       12.9   15.9       18.8      25.0
# 1           NaN   Legend   Midsize       29.2   33.9       38.7      18.0
# 2          Audi       90   Compact       25.9   29.1       32.3      20.0
# 3          Audi      100   Midsize        NaN   37.7       44.6      19.0
# 4           BMW     535i   Midsize        NaN   30.0        NaN      22.0
# ..          ...      ...       ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan       Van       16.6   19.7       22.7      17.0
# 89   Volkswagen   Passat   Compact       17.6   20.0       22.4      21.0
# 90   Volkswagen  Corrado    Sporty       22.9   23.3       23.7      18.0
# 91        Volvo      240   Compact       21.8   22.7       23.5      21.0
# 92          NaN      850   Midsize       24.8   26.7       28.5      20.0
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# ...

# %%
data.info().max("Non-Null Count")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Manufacturer        89 non-null     object
#  1   Model               92 non-null     object
#  2   TypeOfCar           90 non-null     object
#  3   Min.Price           86 non-null     float64
#  4   Price               91 non-null     float64
#  5   Max.Price           88 non-null     float64
#  6   MPG.city            84 non-null     float64
#  7   MPG.highway         91 non-null     float64
#  8   AirBags             87 non-null     object
#  9   DriveTrain          86 non-null     object
#  10  Cylinders           88 non-null     object
#  11  EngineSize          91 non-null     float64
#  12  Horsepower          86 non-null     float64
#  13  RPM                 90 non-null     float64
#  14  Rev.per.mile        87 non-null     float64
# ...

# %%
data.isnull().sum()
# Out:
# Manufacturer           4
# Model                  1
# TypeOfCar              3
# Min.Price              7
# Price                  2
# Max.Price              5
# MPG.city               9
# MPG.highway            2
# AirBags                6
# DriveTrain             7
# Cylinders              5
# EngineSize             2
# Horsepower             7
# RPM                    3
# Rev.per.mile           6
# Man.trans.avail        5
# Fuel.tank.capacity     8
# Passengers             2
# Length                 4
# Wheelbase              1
# Width                  6
# Turn.circle            5
# Rear.seat.room         4
# Luggage.room          19
# Weight                 7
# Origin                 5
# Make                   3
# dtype: int64

# %%
data_sum_nan = data.isnull().sum()
data_sum_nan[data_sum_nan == data_sum_nan.max() ]
# Out:
# Luggage.room    19
# dtype: int64

# %%
data_sum_nan == data_sum_nan.max()
# Out:
# Manufacturer          False
# Model                 False
# TypeOfCar             False
# Min.Price             False
# Price                 False
# Max.Price             False
# MPG.city              False
# MPG.highway           False
# AirBags               False
# DriveTrain            False
# Cylinders             False
# EngineSize            False
# Horsepower            False
# RPM                   False
# Rev.per.mile          False
# Man.trans.avail       False
# Fuel.tank.capacity    False
# Passengers            False
# Length                False
# Wheelbase             False
# Width                 False
# Turn.circle           False
# Rear.seat.room        False
# Luggage.room           True
# Weight                False
# Origin                False
# Make                  False
# dtype: bool

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Manufacturer        89 non-null     object
#  1   Model               92 non-null     object
#  2   TypeOfCar           90 non-null     object
#  3   Min.Price           86 non-null     float64
#  4   Price               91 non-null     float64
#  5   Max.Price           88 non-null     float64
#  6   MPG.city            84 non-null     float64
#  7   MPG.highway         91 non-null     float64
#  8   AirBags             87 non-null     object
#  9   DriveTrain          86 non-null     object
#  10  Cylinders           88 non-null     object
#  11  Horsepower          86 non-null     float64
#  12  RPM                 90 non-null     float64
#  13  Rev.per.mile        87 non-null     float64
#  14  Man.trans.avail     88 non-null     object
# ...

# %%
data.drop(columns=["EngineSize", "Length"])
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1           NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2          Audi       90  Compact       25.9   29.1       32.3      20.0
# 3          Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4           BMW     535i  Midsize        NaN   30.0        NaN      22.0
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7      17.0
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4      21.0
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7      18.0
# 91        Volvo      240  Compact       21.8   22.7       23.5      21.0
# 92          NaN      850  Midsize       24.8   26.7       28.5      20.0
#
#     MPG.highway             AirBags DriveTrain  ... Fuel.tank.capacity  \
# ...

# %%
data.drop(["EngineSize", "Length"], inplace=True, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-127-b278fd1e5988> in <module>
# ----> 1 data.drop(["EngineSize", "Length"], inplace=True, axis=1)
#
# c:\users\lea soussan\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4165                 weight  1.0     0.8
#    4166         """
# -> 4167         return super().drop(
#    4168             labels=labels,
#    4169             axis=axis,
#
# c:\users\lea soussan\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
# ...

# %%
del data["EngineSize"]

# %%
del data["Length"]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Manufacturer        89 non-null     object
#  1   Model               92 non-null     object
#  2   Type                90 non-null     object
#  3   Min.Price           86 non-null     float64
#  4   Price               91 non-null     float64
#  5   Max.Price           88 non-null     float64
#  6   MPG.city            84 non-null     float64
#  7   MPG.highway         91 non-null     float64
#  8   AirBags             87 non-null     object
#  9   DriveTrain          86 non-null     object
#  10  Cylinders           88 non-null     object
#  11  Horsepower          86 non-null     float64
#  12  RPM                 90 non-null     float64
#  13  Rev.per.mile        87 non-null     float64
#  14  Man.trans.avail     88 non-null     object
# ...

# %%
df1 = pd.DataFrame({'fruit': ['apple', 'banana', 'orange'] * 3,
                    'weight': ['high', 'medium', 'low'] * 3,
                    'price': np.random.randint(0, 15, 9)})

df2 = pd.DataFrame({'pazham': ['apple', 'orange', 'pine'] * 2,
                    'kilo': ['high', 'low'] * 3,
                    'price': np.random.randint(0, 15, 6)})

# %%
df1
# Out:
#     fruit  weight  price
# 0   apple    high      0
# 1  banana  medium      2
# 2  orange     low     13
# 3   apple    high      9
# 4  banana  medium     12
# 5  orange     low      8
# 6   apple    high      6
# 7  banana  medium     14
# 8  orange     low     14

# %%
df2
# Out:
#    pazham  kilo  price
# 0   apple  high     12
# 1  orange   low      4
# 2    pine  high     12
# 3   apple   low     12
# 4  orange  high      5
# 5    pine   low      7

# %%
df1.merge(df2, left_on='fruit', right_on='pazham').drop_duplicates(keep='first', inplace=False)
# Out:
#      fruit weight  price_x  pazham  kilo  price_y
# 0    apple   high        0   apple  high       12
# 1    apple   high        0   apple   low       12
# 2    apple   high        9   apple  high       12
# 3    apple   high        9   apple   low       12
# 4    apple   high        6   apple  high       12
# 5    apple   high        6   apple   low       12
# 6   orange    low       13  orange   low        4
# 7   orange    low       13  orange  high        5
# 8   orange    low        8  orange   low        4
# 9   orange    low        8  orange  high        5
# 10  orange    low       14  orange   low        4
# 11  orange    low       14  orange  high        5

# %%
data.concat([df1, df2])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-142-528390cd22de> in <module>
# ----> 1 data.concat([df1, df2])
#
# c:\users\lea soussan\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'concat'

# %%
df1 = pd.DataFrame({'fruit': ['apple', 'banana', 'orange'] * 3,
                    'weight': ['high', 'medium', 'low'] * 3,
                    'price': np.random.randint(0, 15, 9)})

df2 = pd.DataFrame({'pazham': ['apple', 'orange', 'pine'] * 2,
                    'kilo': ['high', 'low'] * 3,
                    'price': np.random.randint(0, 15, 6)})

# %%
pd.concat([df1, df2])
# Out:
#     fruit  weight  price  pazham  kilo
# 0   apple    high      4     NaN   NaN
# 1  banana  medium      3     NaN   NaN
# 2  orange     low      8     NaN   NaN
# 3   apple    high      8     NaN   NaN
# 4  banana  medium      1     NaN   NaN
# 5  orange     low      0     NaN   NaN
# 6   apple    high     14     NaN   NaN
# 7  banana  medium     11     NaN   NaN
# 8  orange     low      9     NaN   NaN
# 0     NaN     NaN      9   apple  high
# 1     NaN     NaN     14  orange   low
# 2     NaN     NaN     13    pine  high
# 3     NaN     NaN      9   apple   low
# 4     NaN     NaN      1  orange  high
# 5     NaN     NaN      7    pine   low

# %%
pd.concat([df1, df2.rename(columns={'pazham': 'fruit', 'kilo':'weight'})])
# Out:
#     fruit  weight  price
# 0   apple    high      4
# 1  banana  medium      3
# 2  orange     low      8
# 3   apple    high      8
# 4  banana  medium      1
# 5  orange     low      0
# 6   apple    high     14
# 7  banana  medium     11
# 8  orange     low      9
# 0   apple    high      9
# 1  orange     low     14
# 2    pine    high     13
# 3   apple     low      9
# 4  orange    high      1
# 5    pine     low      7

# %%
df = pd.DataFrame(["STD,City\tState",
"33,Kolkata\tWest Bengal",
"44,Chennai\tTamil Nadu",
"40,Hyderabad\tTelengana",
"80,Bangalore\tKarnataka"], columns=['row'])

# %%
df
# Out:
#                        row
# 0          STD,City\tState
# 1  33,Kolkata\tWest Bengal
# 2   44,Chennai\tTamil Nadu
# 3  40,Hyderabad\tTelengana
# 4  80,Bangalore\tKarnataka

# %%
split_data = df["STD,City\tState"].str.split(',', '/')
data = split_data.to_list()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\lea soussan\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'STD,City\tState'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
names = ["STD", "City", "tState"]
new_df = pd.DataFrame(data, columns=names)

# %%
df = df['row'].str.replace('\t',',').str.split(',', expand=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\lea soussan\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'row'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df
# Out:
# 0 STD       City        State
# 0  33    Kolkata  West Bengal
# 1  44    Chennai   Tamil Nadu
# 2  40  Hyderabad    Telengana
# 3  80  Bangalore    Karnataka

# %%
df = df['row'].str.replace('\t',',').str.split(',', expand=True)

# %%
df
# Out:
#      0          1            2
# 0  STD       City        State
# 1   33    Kolkata  West Bengal
# 2   44    Chennai   Tamil Nadu
# 3   40  Hyderabad    Telengana
# 4   80  Bangalore    Karnataka

# %%
df.columns = df.iloc[0,:]

# %%
df
# Out:
# 0  STD       City        State
# 0  STD       City        State
# 1   33    Kolkata  West Bengal
# 2   44    Chennai   Tamil Nadu
# 3   40  Hyderabad    Telengana
# 4   80  Bangalore    Karnataka

# %%
df = df.drop(0).reset_index(drop=True)

# %%
df
# Out:
# 0 STD       City        State
# 0  33    Kolkata  West Bengal
# 1  44    Chennai   Tamil Nadu
# 2  40  Hyderabad    Telengana
# 3  80  Bangalore    Karnataka

# %%
pd.read_csv()
# Out:
#     18.0   8   307.0      130.0      3504.      12.0   70  1\t"chevrolet chevelle malibu"
# 0    15.0   8   350.0      165.0      3693.      11...
# 1    18.0   8   318.0      150.0      3436.      11...
# 2    16.0   8   304.0      150.0      3433.      12...
# 3    17.0   8   302.0      140.0      3449.      10...
# 4    15.0   8   429.0      198.0      4341.      10...
# ..                                                 ...
# 392  27.0   4   140.0      86.00      2790.      15...
# 393  44.0   4   97.00      52.00      2130.      24...
# 394  32.0   4   135.0      84.00      2295.      11...
# 395  28.0   4   120.0      79.00      2625.      18...
# 396  31.0   4   119.0      82.00      2720.      19...
#
# [397 rows x 1 columns]

# %%
names = ["mpg", "cylinders", "displacement", "horsepower", "weight", "acceleration", "model_year", "origin", "car_name"]

# %%
df_mpg = pd.read_csv("http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data", header=None, names=names, delim_whitespace=True)

# %%
df_mpg
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0      130.0  3504.0          12.0
# 1    15.0          8         350.0      165.0  3693.0          11.5
# 2    18.0          8         318.0      150.0  3436.0          11.0
# 3    16.0          8         304.0      150.0  3433.0          12.0
# 4    17.0          8         302.0      140.0  3449.0          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0      86.00  2790.0          15.6
# 394  44.0          4          97.0      52.00  2130.0          24.6
# 395  32.0          4         135.0      84.00  2295.0          11.6
# 396  28.0          4         120.0      79.00  2625.0          18.6
# 397  31.0          4         119.0      82.00  2720.0          19.4
#
#      model_year  origin                   car_name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
def scatter_plot(df):
    df['displacement']
    df['acceleration']
    df.xlabel('Displacement')
    df.ylabel('Acceleration')
    dt = df.plot(y, x)
    

scatter_plot(df_mpg)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-190-4587a6eefe6c> in <module>
#       7
#       8
# ----> 9 scatter_plot(df_mpg)
#
# <ipython-input-190-4587a6eefe6c> in scatter_plot(df)
#       2     df['displacement']
#       3     df['acceleration']
# ----> 4     df.xlabel('Displacement')
#       5     df.ylabel('Acceleration')
#       6     dt = df.plot(y, x)
#
# c:\users\lea soussan\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'xlabel'

# %%
def scatter_plot(df):
    df.plot(x='displacement', y='acceleration', kind='scatter')
    
scatter_plot(df_mpg)

# %%
def scatter_plot(df):
    plt.scatter(x=df['displacement'], y=df['acceleration'])
    
scatter_plot(df_mpg)

# %%
def bar_plot(df):
# Out:
#   File "<ipython-input-192-c13691d12b23>", line 1
#     def bar_plot(df):
#                      ^
# IndentationError: expected an indented block

# %%
if def_mpg['car_name'].str.contains('Toyota').any():
    print("toyota car")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-194-ebd357c81350> in <module>
# ----> 1 if def_mpg['car_name'].str.contains('Toyota').any():
#       2     print("toyota car")
#
# NameError: name 'def_mpg' is not defined

# %%
def bar_plot(df):
    df = df.query('car_name.str.contains("toyota") & model_year==78')
    plt.bar(df['car_name'], df['cylinders'])

bar_plot(df_mpg)

# %%
def line_plot(df):
    toyota =df.query('car_name.str.contains("toyota")')
    toyota= toyota[['model_year','weight']]
    toyota_year = toyota.groupby('model_year').agg(np.mean).reset_index()
    plt.plot(toyota_year['model_year'], toyota_year['weight']) 
#     print(toyota_year)

line_plot(df_mpg)
