# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df._get_numeric_data()
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
PassengerId categorical Nominal
Survived Cat. Oridnal 
Pclass  cat Ordinal
Name categorical Nominal
Sex Cat. Ordinal
Age continious 
SibSp cat. nominal
Parch cat. nominal
Ticket cat. nominal
Fare continious 
Cabin nominla
Embarked cat. ordinal
# Out:
#   File "<ipython-input-11-b4ae753ca0ba>", line 1
#     PassengerId categorical Nominal
#                 ^
# SyntaxError: invalid syntax

# %%
age = df.Age

# %%
sex= df.Sex

# %%
plt.bar(sex, age)
plt.show()

# %%
 df["Sex"]= df["Sex"].replace({"male": 0, "female": 1}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-92e477b820ea> in <module>
# ----> 1 df["Sex"]= df["Sex"].replace({"male": 0, "female": 1}, inplace=True)
#
# c:\users\lea soussan\appdata\local\programs\python\python39\lib\site-packages\pandas\core\series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4573         method="pad",
#    4574     ):
# -> 4575         return super().replace(
#    4576             to_replace=to_replace,
#    4577             value=value,
#
# c:\users\lea soussan\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6498                 to_replace, value = keys, values
#    6499
# -> 6500             return self.replace(
#    6501                 to_replace, value, inplace=inplace, limit=limit, regex=regex
# ...

# %%
df

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris   0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1
# 2                               Heikkinen, Miss. Laina   1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1
# 4                             Allen, Mr. William Henry   0  35.0      0
# ..                                                 ...  ..   ...    ...
# ...

# %%
age_group = pd.cut(df.Age,bins=[0,2,12,17,26,65,99],labels=['Toddler/Baby','Child','Teenage','Young Adult','Adult','Elderly'])

# %%
df.insert(5,'Age Group',age_group)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-126-45eea0ceabc3> in <module>
# ----> 1 df.insert(5,'Age Group',age_group)
#
# c:\users\lea soussan\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3626         self._ensure_valid_index(value)
#    3627         value = self._sanitize_column(column, value, broadcast=False)
# -> 3628         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3629
#    3630     def assign(self, **kwargs) -> "DataFrame":
#
# c:\users\lea soussan\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1175         if not allow_duplicates and item in self.items:
#    1176             # Should this be a different kind of error??
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex    Age Group  \
# 0                              Braund, Mr. Owen Harris    0  Young Adult
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1        Adult
# 2                               Heikkinen, Miss. Laina    1  Young Adult
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1        Adult
# 4                             Allen, Mr. William Henry    0        Adult
# ..                                                 ...  ...          ...
# ...

# %%
age_group = df["Age Group"]

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex              int64
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
corr= age.corr(sex)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-281975772868> in <module>
# ----> 1 corr= age.corr(sex)
#
# c:\users\lea soussan\appdata\local\programs\python\python39\lib\site-packages\pandas\core\series.py in corr(self, other, method, min_periods)
#    2331
#    2332         if method in ["pearson", "spearman", "kendall"] or callable(method):
# -> 2333             return nanops.nancorr(
#    2334                 this.values, other.values, method=method, min_periods=min_periods
#    2335             )
#
# c:\users\lea soussan\appdata\local\programs\python\python39\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      69             try:
#      70                 with np.errstate(invalid="ignore"):
# ---> 71                     return f(*args, **kwargs)
#      72             except ValueError as e:
# ...

# %%
df["Age"].corr(df["Sex"])
# Out:
# -0.09325357685567737

# %%
pclass_pivot = df.pivot_table(index="Sex",values="Age")
# pclass_pivot
pclass_pivot.plot.bar()
plt.show()

# %%
age_survival = df.pivot_table(index="Survived",values="Age")
age_survival
# Out:
#                 Age
# Survived
# 0         30.626179
# 1         28.343690

# %%
age_cat = df.pivot_table(index=age_group, values="Survived")

# %%
# survival_by_caegory = df.plot(df["Age_Group"], df["Survived"])
age_survival = df.pivot_table(index="Survived",values="Age_group")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\lea soussan\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age_Group'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
